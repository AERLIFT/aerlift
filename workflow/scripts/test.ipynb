# %%
import xarray as xr

# %%
xr.open_dataset('/Users/markcampmier/Library/Mobile Documents/com~apple~CloudDocs/aerlift/data/3_flagged/anemometer.nc')
# Out:
# <xarray.Dataset> Size: 4MB
# Dimensions:         (sensor: 3, datetime: 64000)
# Coordinates:
#   * sensor          (sensor) <U4 48B 'E102' 'E111' 'G102'
#   * datetime        (datetime) datetime64[ns] 512kB 2022-09-06T14:20:35 ... 2...
# Data variables:
#     air_flow        (sensor, datetime) float64 2MB ...
#     flow_indicator  (sensor, datetime) float64 2MB ...
#     flag_air_flow   (sensor, datetime) int16 384kB ...
#     flag_global     (sensor, datetime) int16 384kB ...
# Attributes: (12/16)
#     campaign:        AERLIFT
#     instrument:      anemometer
#     stage:           flagged
#     created:         2026-03-25T17:59:35.993837
#     script:          workflow/scripts/munge/anemometer.py
#     timezone_local:  America/Los_Angeles
#     ...              ...
#     creator_name:    Mark Campmier, PhD
#     trim_start:      2022-09-01
#     trim_end:        2023-03-31
#     trim_excluded:   []
#     trimmed:         2026-03-26T01:08:30.378267+00:00
# ...
